# %% [markdown]
# # Description
# Trying to find few insights by scrapping form Mouthshut.com which is a verified review platform where people try to speak truth. I tried to scrap about nestaway in part of my learnings

# %%
import requests
from bs4 import BeautifulSoup

# %%
search_query="Nestaway-com-reviews-925868223"
base_url="https://www.mouthshut.com/websites/"

# %%
url= base_url+search_query
print(url)
# Out:
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223

# %%
search_response=requests.get(url)## pass the url to mouthshut an requesting the response
print(search_response)
# Out:
# <Response [200]>

# %%
print(search_response.status_code)
print(search_response.content)
# Out:
# 200
# ...

# %% [markdown]
# #### Response for the code good it has given "Response 200". Let us see what the response content is being beautifully souped

# %%
reviews=BeautifulSoup(search_response.content)
print(reviews)
# Out:
# <!DOCTYPE HTML>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head id="ctl00_ctl00_Head1"><title>
# 	NESTAWAY.COM - Reviews | online | Ratings | Free
# </title>
# <style>
#         .surveylayer {
#             position: fixed;
#             z-index: 1111;
#             background: #fff;
#             left: 34%;
#             top: -581px;
#             border-radius: 5px;
#         }
#
#             .surveylayer section {
#                 margin: 0;
#                 padding: 1px;
#             }
#
#         .surveylayerclose {
#             position: absolute;
#             top: 11px;
#             right: 11px;
#             font-weight: 900 !important;
#             /* background-color: #6f9d20; */
#             padding: 10px;
#             border-radius: 50%;
#             color: #666;
#             font-size: 13px !important;
#         }
#
#         .surveylayer .container {
# ...

# %%
reviews.title
# Out:
# <title>
# 	NESTAWAY.COM - Reviews | online | Ratings | Free
# </title>

# %% [markdown]
# ## Extracting reviews

# %%
review=reviews.find("div",{"class": "left-panel"})

# %%
data=review.find("div", {"class":"read-review-holder"})
print(data)
# Out:
# <div class="read-review-holder" id="dvreview-listing">
# <div class="row">
# <h2 class="pull-left">
#                                         Nestaway.com Reviews
#                                     </h2>
# <div class="pull-right selectbox-container" id="ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_dvSorting" style="margin-top: 0;">
# <select id="ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_ddlSorting" name="ctl00$ctl00$ContentPlaceHolderFooter$ContentPlaceHolderBody$ddlSorting" onchange="dopaging(this);">
# <option value="4">Most Read</option>
# <option selected="selected" value="0">Latest</option>
# <option value="1">Product Rating</option>
# <option value="2">Review Usefulness</option>
# <option style="display:none" value="3">Followers</option>
# <option style="display:none" value="5">Most Helpful</option>
# </select>
# <span class="icon-drop-down"></span>
# </div>
# </div>
# ...

# %% [markdown]
# ## Writing a function to extract text form the data

# %%
new=[]
def test(review):
    for x in review:
        new.append(x.text)
    return new

# %%
reviews_1=data.findAll('div', {"class":"more reviewdata"})
print(reviews_1)
print(len(reviews_1))
# Out:
# [<div class="more reviewdata">                                            I am the owner given 10 flats to nestaway for 1 year, they made me to feel like am the big idiot who gave hard earned money to this people, they very good in giving false promises, they make very good money by cheating tenant as well as owner, no follow up simply rejecting your callif contin...<a onclick="bindreviewcontent('3051768',this,false,'I found this review of Nestaway.com pretty useful',925868223,'.png','I found this review of Nestaway.com pretty useful %23WriteShareWin','https://www.mouthshut.com/review/Nestaway-com-review-uopstrsmqlo','Nestaway.com',' 1/5','uopstrsmqlo');" style="cursor:pointer">Read More</a></div>, <div class="more reviewdata">                                            The services provided by Nestaway EC hub is not at all satisfactory.They asked me to visit the hub so that we can plan visit to multiple properties in EC.When I reached the center/hub none of the agents were available
# ...

# %%
def extractReview(Review):
    r=[]
    for  i in Review:
        r.append(i.text)
    return r

# %% [markdown]
# ### Trying to get full review 1 on 1 by extracting "Read MOre" data

# %%
review_1= extractReview(reviews_1)
print(review_1)
# Out:
# ['                                            I am the owner given 10 flats to nestaway for 1 year, they made me to feel like am the big idiot who gave hard earned money to this people, they very good in giving false promises, they make very good money by cheating tenant as well as owner, no follow up simply rejecting your callif contin...Read More', '                                            The services provided by Nestaway EC hub is not at all satisfactory.They asked me to visit the hub so that we can plan visit to multiple properties in EC.When I reached the center/hub none of the agents were available and when asked I was informed that agents are on emergency leave.T...Read More', "                                            Unprofessional and unorganized system. I am staying in a room in which the bathroom doesn't have a door. And they are not fixing it. One of the worst and unprofessional service provider. It's a fraud. Nestaway is charging users a lot of money. Don't choose
# ...

# %%
readmore=data.find("a",{"onclick":"bindreviewcontent('3041453',this,false,'I found this review of Nestaway.com pretty useful',925868223,'.png','I found this review of Nestaway.com pretty useful %23WriteShareWin','https://www.mouthshut.com/review/Nestaway-com-review-mqlroqpmplo','Nestaway.com',' 1/5','mqlroqpmplo');"})

# %% [markdown]
# ### Trying to find out how many reviews are there exactly

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Options for pandas
pd.options.display.max_columns = None
pd.options.display.max_rows = None

pd.options.display.max_colwidth=-1

# Display all cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

from IPython import get_ipython
ipython = get_ipython()
import re

# %%
total_reviews=reviews.find("span",{"id":"ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_lblnoofrecords"})

# %%
total_review=total_reviews.text
total_review
# Out:
# 'Showing: 1 - 20 of 347 Reviews on Nestaway.com'

# %%
total_review=total_review.replace("Showing: 1 - 20 of ","")
print(total_review)
total_review=re.sub(" Reviews.*","",total_review)
print(total_review)
# Out:
# 347 Reviews on Nestaway.com
# 347

# %% [markdown]
# ## let me find out how many pages we have if a page show 20 reviews

# %%
total_review=int(total_review)

# %%
total_pages=total_review//20

if total_pages%20!=0:
    total_pages=total_pages+1
print(total_pages)
# Out:
# 18

# %%
reviews_url=[]
for more_div in reviews_1:
    review_url=more_div.find("a")['onclick']
    reviews_url.append(review_url)

reviews_url
# Out:
# ["bindreviewcontent('3051768',this,false,'I found this review of Nestaway.com pretty useful',925868223,'.png','I found this review of Nestaway.com pretty useful %23WriteShareWin','https://www.mouthshut.com/review/Nestaway-com-review-uopstrsmqlo','Nestaway.com',' 1/5','uopstrsmqlo');",
#  "bindreviewcontent('3047533',this,false,'I found this review of Nestaway.com pretty useful',925868223,'.png','I found this review of Nestaway.com pretty useful %23WriteShareWin','https://www.mouthshut.com/review/Nestaway-com-review-rmmmooqsplo','Nestaway.com',' 1/5','rmmmooqsplo');",
#  "bindreviewcontent('3046342',this,false,'I found this review of Nestaway.com pretty useful',925868223,'.png','I found this review of Nestaway.com pretty useful %23WriteShareWin','https://www.mouthshut.com/review/Nestaway-com-review-pturnporplo','Nestaway.com',' 1/5','pturnporplo');",
# ...

# %%
urls=[]

for review_url in reviews_url:
    review_url=review_url.replace('bindreviewcontent',"")
    review_url=review_url.replace(";","")
    review_url=review_url.replace('"',"")
    review_url=review_url.strip("()")
    ## Convert the review url string to tuple or split on comma 
    review_url_split=review_url.split(",")
    #print(review_url_split)
    #If a value after splitting starts with "https:" it is tghe url of the review
    url=[value for value in review_url_split if "www.mouthshut.com/review" in value][0]
    urls.append(url)

# %%
for review_url in reviews_url:
    review_url=review_url.replace('bindreviewcontent',"")
    review_url=review_url.replace(";","")
    review_url=review_url.replace('"',"")
    review_url=review_url.strip("()")
    ## Convert the review url string to tuple or split on comma 
    review_url_split=review_url.split(",")

# %%
review_url1=urls[0]
review_url1
# Out:
# "'https://www.mouthshut.com/review/Nestaway-com-review-uopstrsmqlo'"

# %%
def cleancontent(urls):
    print(urls)
    search_response1=requests.get(urls)
    print(search_response1)
    search_response1.status_code
    #search_response1.content
    reviews=BeautifulSoup(search_response.content)
    reviews.prettify
    return reviews

# %%
review_url1=cleancontent(urls[0])
# Out:
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-1
# <Response [200]>

# %%
exactreview=review_url1.find("div",{"class": "left-panel"})

# %%
exact=exactreview.find("div", {"class":"read-review-holder"})
print(exact)
# Out:
# <div class="read-review-holder" id="dvreview-listing">
# <div class="row">
# <h2 class="pull-left">
#                                         Nestaway.com Reviews
#                                     </h2>
# <div class="pull-right selectbox-container" id="ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_dvSorting" style="margin-top: 0;">
# <select id="ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_ddlSorting" name="ctl00$ctl00$ContentPlaceHolderFooter$ContentPlaceHolderBody$ddlSorting" onchange="dopaging(this);">
# <option value="4">Most Read</option>
# <option selected="selected" value="0">Latest</option>
# <option value="1">Product Rating</option>
# <option value="2">Review Usefulness</option>
# <option style="display:none" value="3">Followers</option>
# <option style="display:none" value="5">Most Helpful</option>
# </select>
# <span class="icon-drop-down"></span>
# </div>
# </div>
# ...

# %%
exactrow=exact.find('div',{"class":"row review-article"})
print(exactrow)
# Out:
# <div class="row review-article"><div class="row"><div class="col-2 profile" id="ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_rptreviews_ctl00_divProfile"><script> getuserprofile(3051768,537637,0,0,0,'','ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_rptreviews_ctl00_divProfile',1,'ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_rptreviews_ctl00_spnview','ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_rptreviews_ctl00_smdatetime')</script></div><div class="col-10 review" id="ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_rptreviews_ctl00_lireviewdetails"><div class="review-arrow"></div><strong><a href="https://www.mouthshut.com/review/Nestaway-com-review-uopstrsmqlo" id="ctl00_ctl00_ContentPlaceHolderFooter_ContentPlaceHolderBody_rptreviews_ctl00_lnkTitle" target="_blank">NEASTAWAY SUCH A WORTHLESS COMPANY</a></strong><!-- --><div class="rating"><span><i class="icon-rating rated-star"></i><i class="icon-rating unrated-s
# ...

# %%
reviews_exact=exactrow.find('div', {"class":"rev-main-content"})
print(reviews_exact)
# Out:
# None

# %%
urls=[]
for i in range(1,19):
    url="https://www.mouthshut.com/websites/"
    query="Nestaway-com-reviews-925868223""-page-"+str(i)
    print (url+query)
    urls.append(url+query)
# Out:
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-1
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-2
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-3
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-4
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-5
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-6
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-7
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-8
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-9
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-10
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-11
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-12
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-13
# ...

# %% [markdown]
# ## A full function to scrap all the review and ratings by using 1 Url

# %%
def getreviewUrl(urls):
    reviews=cleancontent(urls)   
    review=reviews.find("div",{"class": "left-panel"})
    data=review.find("div", {"class":"read-review-holder"})
    reviews_1=data.findAll('div', {"class":"more reviewdata"})
    reviews= extractReview(reviews_1)
    
    rating=review.findAll('div',{"class":"rating"})
    ratings=[]
    for x in rating:
        rating=x.findAll("i",{"class":"icon-rating rated-star"})
        ratings.append(len(rating))
    #print(len(review))
    #print(review)
        
    nestaway=pd.DataFrame()
    nestaway['ratings']=ratings
    nestaway['reviews']=reviews
    return nestaway

# %%
nestaway=getreviewUrl(urls[0])
# Out:
# https://www.mouthshut.com/websites/Nestaway-com-reviews-925868223-page-1
# <Response [200]>

# %%
rating=review.findAll('div',{"class":"rating"})
ratings=[]
for x in rating:
    rating=x.findAll("i",{"class":"icon-rating rated-star"})
    ratings.append(len(rating))

# %%
print(len(ratings))
# Out:
# 20

# %%
nestaway
# Out:
#     ratings  \
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1
# 5   5
# 6   1
# 7   1
# 8   1
# 9   1
# 10  1
# 11  4
# 12  5
# 13  1
# 14  1
# 15  1
# 16  4
# 17  1
# 18  1
# 19  1
#
#                                                                                                                                                                                                                                                                                                                                                                                                     reviews
# 0                                               I am the owner given 10 flats to nestaway for 1 year, they made me to feel like am the big idiot who gave hard earned money to this people, they very good in giving false promises, they make very good money by cheating tenant as well as owner, no follow up simply rejecting your callif contin...Read More
# ...

# %%
nestaway1=getreviewUrl(urls[1])

# %%
nestaway2=getreviewUrl(urls[2])

# %%
nestaway3=getreviewUrl(urls[3])

# %%
nestaway4=getreviewUrl(urls[4])

# %%
nestaway5=getreviewUrl(urls[5])

# %%
nestaway6=getreviewUrl(urls[6])

# %%
nestaway7=getreviewUrl(urls[7])

# %%
nestaway8=getreviewUrl(urls[8])

# %%
nestaway9=getreviewUrl(urls[9])

# %%
nestaway10=getreviewUrl(urls[10])

# %%
nestaway11=getreviewUrl(urls[11])

# %%
nestaway12=getreviewUrl(urls[12])

# %%
nestaway13=getreviewUrl(urls[13])

# %%
nestaway14=getreviewUrl(urls[14])

# %%
nestaway15=getreviewUrl(urls[15])

# %%
nestaway16=getreviewUrl(urls[16])

# %%
nestaway17=getreviewUrl(urls[17])

# %%
nestaway0=getreviewUrl(url)

# %%
nestaway_reviews=pd.concat([nestaway0, nestaway, nestaway1, nestaway2, nestaway3, nestaway4, nestaway5, nestaway6, nestaway7, nestaway8, nestaway9, nestaway10, nestaway11, nestaway12, nestaway13, nestaway14, nestaway15, nestaway16, nestaway17 ])

# %%
nestaway_reviews.shape

# %% [markdown]
# ### I have got 380 reviews it can be repeated reviews

# %%
nestaway_reviews.to_csv("nestaway.csv")

# %% [markdown]
# ## I have successfully saved my scraped reviews in a CSV file
